# %% [markdown]
# # Segmentation with K-Means
# Source taken from https://machinelearningknowledge.ai/image-segmentation-in-python-opencv/

# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2 as cv

# %%
img = cv.cvtColor(cv.imread('./img/itsohk_beach.jpg'), cv.COLOR_BGR2RGB)
plt.imshow(img); plt.title('Original'); plt.show()

# %%
img_2d = img.reshape((-1,3))
img_2d = np.float32(img_2d)

# reshape image to be list of 3 channel colors
print(img_2d.shape)
# Out:
# (149850, 3)

# %%
# define criteria for k-Means algorithm
criteria = (cv.TERM_CRITERIA_EPS + cv.TERM_CRITERIA_MAX_ITER, 10, 1.0)
attempts=10

# %%
# apply k-means for K=2
K = 2
ret,label,center=cv.kmeans(img_2d,K,None,criteria,attempts,cv.KMEANS_PP_CENTERS)
center = np.uint8(center)
res = center[label.flatten()]
result_image = res.reshape((img.shape))

plt.imshow(result_image); plt.title('Result with K=2'); plt.show()

plt.figure()
plt.title('Cluster Visualization')
for cl in range(K):
     img_cl = img_2d[label.ravel()==cl]
     #plt.scatter(img_cl[:,0], img_cl[:,1])
     plt.scatter(img_cl[:,0], img_cl[:,2])

plt.scatter(center[:,0], center[:,2], s = 80, c='y', marker = 's')
plt.show()

# %%
# apply k-means for K=2
K = 3
ret,label,center=cv.kmeans(img_2d,K,None,criteria,attempts,cv.KMEANS_PP_CENTERS)
center = np.uint8(center)
res = center[label.flatten()]
result_image = res.reshape((img.shape))

plt.imshow(result_image); plt.title('Result with K=3'); plt.show()

plt.figure()
plt.title('Cluster Visualization')
for cl in range(K):
     img_cl = img_2d[label.ravel()==cl]
     #plt.scatter(img_cl[:,0], img_cl[:,1])
     plt.scatter(img_cl[:,0], img_cl[:,2])
     
plt.scatter(center[:,0], center[:,2], s = 80, c='y', marker = 's')
plt.show()

# %%
K = 4
ret,label,center=cv.kmeans(img_2d,K,None,criteria,attempts,cv.KMEANS_PP_CENTERS)
center = np.uint8(center)
res = center[label.flatten()]
result_image = res.reshape((img.shape))

plt.imshow(result_image); plt.title('Result with K=4'); plt.show()

plt.figure()
plt.title('Cluster Visualization')
for cl in range(K):
     img_cl = img_2d[label.ravel()==cl]
     #plt.scatter(img_cl[:,0], img_cl[:,1])
     plt.scatter(img_cl[:,0], img_cl[:,2])

plt.scatter(center[:,0], center[:,2], s = 80, c='y', marker = 's')
plt.show()

# %% [markdown]
# # Aufgabe: Implementieren Sie k-means zur Farbclusterung
