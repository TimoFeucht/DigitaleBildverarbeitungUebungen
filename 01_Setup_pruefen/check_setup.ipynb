# %% [markdown]
# # Teste das vorhandene Setup

# %% [markdown]
# ## Importiere notwendige Bibliotheken

# %%
import numpy as np
import pandas as pd
import cv2
from matplotlib import pyplot as plt
import scipy

# %% [markdown]
# ## Lade Bild und zeige es in eigenem Fenster an

# %%
# lade Bild und zeige es in eigenem Fenster an
img=cv2.imread('./img/lena_std.tif', cv2.IMREAD_COLOR)
cv2.imshow('Testbild Lena, www.lenna.org', img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ## Lade Bild und zeige es "Inline" an

# %%
# zeige Bild innerhalb des Notebooks an
# %matplotlib inline
img = cv2.imread('./img/lena_std.tif', cv2.IMREAD_COLOR)
plt.figure()
plt.imshow(img)
# konvertiere Bildfarben
plt.figure()
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)
plt.show()

# %% [markdown]
# ## Teste Numpy und SciPy Installation

# %%
if(np.pi == scipy.pi):
    print('Konnte PI aus Numpy und SciPy-Libs auslesen und vergleichen.')
else:
    print('Es gab einen Fehler.')
# Out:
# Konnte PI aus Numpy und SciPy-Libs auslesen und vergleichen.

# %% [markdown]
# ## Bildkoordinatensystem

# %%
# Zeige die ersten 25 Spalten des Bildes an
plt.figure()
plt.imshow(img_rgb[:,0:24])
plt.show()

# %%
# ToDo: Zeige die ersten 50 Zeilen des Bildes an
plt.figure()
plt.imshow(img_rgb[0:49,:]) # Zeige ersten 50 Zeilen und alle Spalten des Bildes an
plt.show()

# %%
# ToDo: Zeige die einzelnen Farbkanäle Kanal des Bildes als 3x Grauwert-Bilder an
# Anmerkung: plt.imshow(img[...], cmap='gray', vmin=0, vmax=255) ermöglicht die Darstellung als Grauwert-Bild
# und verhindert durch vmin und vmax die automatische Skalierung der Pixelwerte

# zeige Farbkanal rot als Grauwert-Bild dan
plt.figure()
print("Farbkanal \"r\" als Grauwert-Bild")
plt.imshow(img_rgb[:,:,0], cmap='gray', vmin=0, vmax=255)
plt.show()

# zeige Farbkanal grün als Grauwert-Bild dan
plt.figure()
print("Farbkanal \"g\" als Grauwert-Bild")
plt.imshow(img_rgb[:,:,1], cmap='gray', vmin=0, vmax=255)
plt.show()

# zeige Farbkanal blau als Grauwert-Bild dan
plt.figure()
print("Farbkanal \"b\" als Grauwert-Bild")
plt.imshow(img_rgb[:,:,2], cmap='gray', vmin=0, vmax=255)
plt.show()
# Out:
# Farbkanal "r" als Grauwert-Bild
# Farbkanal "g" als Grauwert-Bild
# Farbkanal "b" als Grauwert-Bild
